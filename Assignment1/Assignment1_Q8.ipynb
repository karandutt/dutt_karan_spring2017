# %%
import nltk

# %%
from nltk.corpus import nps_chat, words

# %%
x = words.words()[50:75]
print(x)
# Out:
# ['abandoner', 'abandonment', 'Abanic', 'Abantes', 'abaptiston', 'Abarambo', 'Abaris', 'abarthrosis', 'abarticular', 'abarticulation', 'abas', 'abase', 'abased', 'abasedly', 'abasedness', 'abasement', 'abaser', 'Abasgi', 'abash', 'abashed', 'abashedly', 'abashedness', 'abashless', 'abashlessly', 'abashment']

# %%
all_words = list(nps_chat.words('10-19-20s_706posts.xml'))
print(all_words)[50:75]
# Out:
# ['now', 'im', 'left', 'with', 'this', 'gay', 'name', ':P', 'PART', 'hey', 'everyone', 'ah', 'well', 'NICK', ':', 'U7', 'U7', 'is', 'a', 'gay', 'name', '.', '.', 'ACTION', 'gives', 'U121', 'a', 'golf', 'clap', '.', ':)', 'JOIN', 'hi', 'U59', '26', '/', 'm', '/', 'ky', 'women', 'that', 'are', 'nice', 'please', 'pm', 'me', 'JOIN', 'PART', 'there', 'ya', 'go', 'U7', 'do', "n't", 'golf', 'clap', 'me', '.', 'fuck', 'you', 'U121', ':@', 'whats', 'everyone', 'up', 'to', '?', 'PART', 'PART', 'i', "'ll", 'thunder', 'clap', 'your', 'ass', '.', 'PART', 'and', 'i', 'dont', 'even', 'know', 'what', 'that', 'means', '.', 'that', 'sounds', 'painful', 'any', 'ladis', 'wanna', 'chat', '?', '29', 'm', '26', '/', 'm', 'JOIN', 'my', 'cousin', 'drew', 'a', 'messed', 'up', 'pic', 'on', 'my', 'cast', 'PART', '24', '/', 'm', 'boo', '.', '26', '/', 'm', 'and', 'sexy', 'lol', 'U115', 'boo', '.', 'JOIN', 'PART', 'he', 'drew', 'a', 'girl', 'with', 'legs', 'spread', 'boo', '.', 'hope', 'he', 'didnt', 'draw', 'a', 
# ...

# %%
set(x)^set(all_words)
# Out:
# {'!',
#  '!!',
#  '!!!',
#  '!!!!',
#  '!!!!!',
#  '!!!!!!',
#  '!!!!!!!',
#  '!!!!!!!!!!!!!!!!',
#  '!.',
#  '"',
#  '#',
#  '&',
#  "'",
#  "'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  '(',
#  ')',
#  '*',
#  '*sniffs*',
#  '*spank*',
#  ',',
#  '-',
#  '--------------------',
#  '--------->',
#  '.',
#  '. . .',
#  '..',
#  '...',
#  '....',
#  '......',
#  '/',
#  '1-900-anal-sex',
#  '1.99',
#  '14',
#  '2',
#  '20s',
#  '22',
#  '24',
#  '26',
#  '27',
#  '29',
#  '30',
#  '31',
#  '8082653953',
#  ':',
#  ':(',
#  ':)',
#  ':-o',
#  ':@',
#  ':P',
#  ';)',
#  '=',
#  '=-\\',
#  '>:->',
#  '?',
#  '??',
#  '???',
#  '????',
#  '@',
#  'A',
#  'ACTION',
#  'ALL',
#  'ANYONE',
#  'Abanic',
#  'Abantes',
#  'Abarambo',
#  'Abaris',
#  'Abasgi',
#  'And',
#  'Any',
#  'Anyone',
#  'Aw',
#  'B',
#  'Box',
#  'But',
#  'CA',
#  'CHOCO',
#  'CO',
#  'Changing',
#  'Check',
#  'Compliments',
#  'Connected',
#  'Considerably',
#  'Cradle',
#  'Cum',
#  'DIRTY',
#  'Days',
#  'Death',
# ...
